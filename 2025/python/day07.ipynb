# %%
import helper

INPUTS = helper.get_input(day=7)
TEST_INPUTS = """
""".strip()

print(TEST_INPUTS)

# %% [markdown]
# ## Part 1

# %%
def part1(inputs) -> int:
    result = 0
    return result


helper.run_part(
    func=part1,
    test_inputs=TEST_INPUTS,
    test_expected=0,
    real_inputs=INPUTS,
)
# Out:
# --- TEST ---
# >> EXPECTED: 0
# >> RESULT:   0 ✅
#
# --- REAL ---
# >> RESULT:   0

# %% [markdown]
# ## Part 2

# %%
def part2(inputs) -> int:
    result = 0
    return result


helper.run_part(
    func=part2,
    test_inputs=TEST_INPUTS,
    test_expected=0,
    real_inputs=INPUTS,
)
# Out:
# --- TEST ---
# >> EXPECTED: 0
# >> RESULT:   0 ✅
#
# --- REAL ---
# >> RESULT:   0
